# %% [markdown]
# # Deep Learning Exercise
# Below you'll find a data science exercise that may be solved with deep learning techniques.  While you're encouraged to use deep learning, this problem can certainly be solved other ways.  Be sure to document your thought processes and justify *why* you used your solution.
#
# ## Limits
# You shouldn't spend longer than 1-2 hours on this exercise.  You won't be timed so be sure to relax and choose a time that suits you.  It's perfectly acceptable if you don't complete the exercise.  Just be sure to document your progress and explain your strategies.  You're encouraged to use and cite prior research.
#
# ## The Problem
# The goal of this exercise is to build a reliable heartbeat detector given electrocardiogram (ECG) data.
#
# ## The Data
# For this exercise we'll be using ECG data from the [MIT-BIH Arrhythmia Database](https://www.physionet.org/physiobank/database/mitdb/).  There's a handy tool [here](https://physionet.org/cgi-bin/atm/ATM) for converting this data to more usable formats.  The first data file, `100m.mat`, is already in the same directory as this notebook so you won't need to download anything unless you wish to collect more data.  If you do, use the [ATM](https://physionet.org/cgi-bin/atm/ATM) to export `.mat` files.  The annotations are obtained by selecting `Show annotations as text`.  Be sure to move the `Aux` column if you import more annotations.
#
# ## Let's get started!

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import scipy.io as io
from scipy import signal
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Importing ECG data
# We'll start by importing our ECG data.  There are two channels available and we'll be using the MLII channel.

# %%
signals = io.loadmat('100m.mat')
annotations = np.genfromtxt('annotations.txt',
                            dtype=[('time','|S9'),('sample','f'),('type','|S1')],
                            skip_header=1)

# The first channel contains MLII recordings
mlii_samples = signals['val'][0]

# %% [markdown]
# Let's check out what this data looks like.  Hopefully we'll see a heartbeat!

# %%
plt.plot(mlii_samples[:1000])

# %% [markdown]
# For training, we'll divide this data into a number of random 1000 sample long chunks.  We'll generate two sets of data: the raw samples and their spectral counterparts.

# %%
chunk_size = 1000
sample_size = 1000

# Generate random chunk indexes
sample_chunk_idx = np.random.randint(1, mlii_samples.size - chunk_size, sample_size)
sample_chunk_idx = np.array(np.rot90([sample_chunk_idx, sample_chunk_idx + chunk_size]))

sample_chunks = []
sample_chunks_f = []

# We'll use this hamming window for the STFT
stft_size = 32
hamming_window = signal.get_window('hamming', stft_size)

# Construct our main sample data set
for range in sample_chunk_idx:
  sample_chunks.append(mlii_samples[range[0]: range[1]])

# Things tend to work slightly better when rescaled to 0..1
scaler = MinMaxScaler(feature_range=(0, 1))
sample_chunks = scaler.fit_transform(sample_chunks)

# Compute the spectra for each chunk
for sample in sample_chunks:
  f, t, Zxx = signal.stft(sample, window = hamming_window, nperseg = stft_size)
  sample_chunks_f.append(np.abs(Zxx))

# Recast as a numpy array
sample_chunks_f = np.asarray(sample_chunks_f)

# %% [markdown]
# Our two sets of sample data now look like:

# %%
fig, axs = plt.subplots(1, 2, figsize=(13, 3))
axs[0].plot(sample_chunks[0])  # Sample Chunks
axs[1].pcolormesh(sample_chunks_f[2]) # Computed Spectra for each chunk

# %% [markdown]
# Now for our label data.  We'll construct a few label sets: indexes and one-hot encoded for both raw and spectra.

# %%
beats = annotations['sample']
sample_beats = []
sample_beats_oh = np.zeros((sample_size, chunk_size), dtype = int)
sample_beats_f_oh = np.zeros((sample_size, sample_chunks_f.shape[2]), dtype = int)

for i, chunk in enumerate(sample_chunk_idx):
    sample_beats.append(beats[np.where(np.logical_and(beats >= chunk[0], beats <= chunk[1]))])
    offset_beats = ((sample_beats[i] - sample_chunk_idx[i][0]) - 1).astype(int)
    sample_beats_oh[i, offset_beats] = 1
    sample_beats_f_oh[i, (offset_beats / stft_size * 2).astype(int)] = 1

# Recast as numpy array
sample_beats = np.asarray(sample_beats)

# %% [markdown]
# Let's plot our sample data together with our label data to ensure they line up:

# %%
fig, axs = plt.subplots(1, 2, figsize=(13, 3))
s_num = 4
# Plot 1
axs[0].plot(sample_chunks[0])
for xc in np.where(sample_beats_oh[0] == 1)[0]:
    axs[0].axvline(x = xc, linewidth=15, color='g', alpha=0.2)

# Plot 2
axs[1].pcolormesh(sample_chunks_f[0])
for xc in np.where(sample_beats_f_oh[0] == 1)[0]:
    axs[1].axvline(x = xc, linewidth=15, color='y', alpha=0.2)

# %%
fig, axs = plt.subplots(1,2, figsize=(13, 3))

axs[0].plot(sample_chunks[1])
for xc in np.where(sample_beats_oh[1] == 1)[0]:
    axs[0].axvline(x = xc, linewidth=15, color='g', alpha=0.2)
    
    
    # Plot 2
axs[1].pcolormesh(sample_chunks_f[1])
for xc in np.where(sample_beats_f_oh[1] == 1)[0]:
    axs[1].axvline(x = xc, linewidth=15, color='y', alpha=0.2)

# %%
fig, axs = plt.subplots(1,2, figsize=(13, 3))

axs[0].plot(sample_chunks[3])
for xc in np.where(sample_beats_oh[3] == 1)[0]:
    axs[0].axvline(x = xc, linewidth=15, color='g', alpha=0.2)
    
    
    # Plot 2
axs[1].pcolormesh(sample_chunks_f[3])
for xc in np.where(sample_beats_f_oh[3] == 1)[0]:
    axs[1].axvline(x = xc, linewidth=15, color='y', alpha=0.2)

# %% [markdown]
# Now it's your turn!  Using any or all of the data sets provided, build a deep learning model that predicts the location of heartbeats given a sample of ECG data.
#
# To summarize your available data:
#
#     sample_chunks: raw samples
#     sample_beats: beat index locations (0-indexed)
#     sample_beats_oh: one-hot encoded beat locations
#     sample_chunks_f: spectra of samples
#     sample_beats_f_oh: beat index locations for spectra

# %%
# We can see signals at specific locations in the time series data
for xc in np.where(sample_beats_oh[0] == 1)[0]:
    print xc
# Out:
# 210
# 503
# 798

# %%
#Setup training data
data = sample_chunks
labels = sample_beats_oh

# %%
from sklearn.decomposition import PCA

# M = normalize(data)
pca = PCA(n_components=np.shape(data)[1]) 
T = pca.fit_transform(data) 
T.shape
# Out:
# (1000, 1000)

# %%
cumulative_explained = np.cumsum(pca.explained_variance_ratio_) 
plt.figure(figsize=(7,5))
plt.plot(cumulative_explained*100);
plt.ylim([40,100])
plt.grid()
plt.title('PCA of Time Series', fontsize=12)
plt.ylabel('% Variance Explained')
plt.xlabel('Number of Principle Components')

print(pca.explained_variance_ratio_[:10])
# Out:
# [ 0.04312326  0.02812531  0.02680288  0.02379311  0.02096596  0.02007305
#   0.01944452  0.01900288  0.0177193   0.01652651]

# %%
pca = PCA(n_components=300) 
data_pca = pca.fit_transform(data) 
labels_pca = pca.fit_transform(labels)

# %%
data_pca.shape
# Out:
# (1000, 300)

# %%
from sklearn.model_selection import train_test_split
#Split the data for training and testing, automatically randomizes sample selection
data_train, data_test, labels_train, labels_test = train_test_split(data, labels, test_size=0.33, random_state=42)

# %%
data_train.shape
# Out:
# (670, 1000)

# %% [markdown]
# # Neural Network Model

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(units=64, input_shape=(1000, 670)))   # Units = dimensionality of output space for first layer
model.add(Activation('relu'))
model.add(Dense(units=25))
model.add(Activation('relu'))
model.add(Dense(units=25))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True))


# x_train and y_train are Numpy arrays --just like in the Scikit-Learn API.
model.fit(data_train, labels_train, epochs=5, batch_size=32)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-110-c81a463d7ce3> in <module>()
#      16
#      17 # x_train and y_train are Numpy arrays --just like in the Scikit-Learn API.
# ---> 18 model.fit(data_train, labels_train, epochs=5, batch_size=32)
#
# /usr/lib64/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     854                               class_weight=class_weight,
#     855                               sample_weight=sample_weight,
# --> 856                               initial_epoch=initial_epoch)
#     857
#     858     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1427             class_weight=class_weight,
#    1428             check_batch_axis=False,
# -> 1429             batch_size=batch_size)
#    1430         # Prepare validation data.
#    1431         if validation_data:
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1303                                     self._feed_input_shapes,
#    1304                                     check_batch_axis=False,
# -> 1305                                     exception_prefix='input')
#    1306         y = _standardize_input_data(y, self._feed_output_names,
#    1307                                     output_shapes,
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     137                             ' to have shape ' + str(shapes[i]) +
#     138                             ' but got array with shape ' +
# --> 139                             str(array.shape))
#     140     return arrays
#     141
#
# ValueError: Error when checking input: expected dense_55_input to have shape (None, 1000, 670) but got array with shape (670, 1000, 1)

# %%
data_train = np.reshape(data_train, data_train.shape + (1,))
data_test = np.reshape(data_test, data_test.shape + (1,))

# %%
model = Sequential()
model.add(LSTM(128, input_shape = data_train.shape[1:]))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(data_train, labels_train, epochs=100, batch_size=1, verbose=2)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-88-62a9a1712d1f> in <module>()
#       3 model.add(Dense(1))
#       4 model.compile(loss='mean_squared_error', optimizer='adam')
# ----> 5 model.fit(data_train, labels_train, epochs=100, batch_size=1, verbose=2)
#
# /usr/lib64/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     854                               class_weight=class_weight,
#     855                               sample_weight=sample_weight,
# --> 856                               initial_epoch=initial_epoch)
#     857
#     858     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1427             class_weight=class_weight,
#    1428             check_batch_axis=False,
# -> 1429             batch_size=batch_size)
#    1430         # Prepare validation data.
#    1431         if validation_data:
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1307                                     output_shapes,
#    1308                                     check_batch_axis=False,
# -> 1309                                     exception_prefix='target')
#    1310         sample_weights = _standardize_sample_weights(sample_weight,
#    1311                                                      self._feed_output_names)
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     137                             ' to have shape ' + str(shapes[i]) +
#     138                             ' but got array with shape ' +
# --> 139                             str(array.shape))
#     140     return arrays
#     141
#
# ValueError: Error when checking target: expected dense_35 to have shape (None, 1) but got array with shape (670, 1000)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(1,1000)))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(data_train, labels_train, epochs=100, batch_size=1, verbose=2)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-97-a8de76095bfd> in <module>()
#       4 model.add(Activation('sigmoid'))
#       5 model.compile(loss='mean_squared_error', optimizer='adam')
# ----> 6 model.fit(data_train, labels_train, epochs=100, batch_size=1, verbose=2)
#
# /usr/lib64/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     854                               class_weight=class_weight,
#     855                               sample_weight=sample_weight,
# --> 856                               initial_epoch=initial_epoch)
#     857
#     858     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1427             class_weight=class_weight,
#    1428             check_batch_axis=False,
# -> 1429             batch_size=batch_size)
#    1430         # Prepare validation data.
#    1431         if validation_data:
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1303                                     self._feed_input_shapes,
#    1304                                     check_batch_axis=False,
# -> 1305                                     exception_prefix='input')
#    1306         y = _standardize_input_data(y, self._feed_output_names,
#    1307                                     output_shapes,
#
# /usr/lib64/python2.7/site-packages/keras/engine/training.pyc in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     125                                  ' to have ' + str(len(shapes[i])) +
#     126                                  ' dimensions, but got array with shape ' +
# --> 127                                  str(array.shape))
#     128             for j, (dim, ref_dim) in enumerate(zip(array.shape, shapes[i])):
#     129                 if not j and not check_batch_axis:
#
# ValueError: Error when checking input: expected lstm_19_input to have 3 dimensions, but got array with shape (670, 1000)

# %%
# x_train and y_train are Numpy arrays --just like in the Scikit-Learn API.
model.fit(data_train, labels_train, epochs=5, batch_size=32)

# %%
data_train.shape
# Out:
# (670, 1000)

# %%
data_train.shape[1:]
# Out:
# (1000, 1)

# %%
from keras.layers import Input, LSTM, RepeatVector
from keras.models import Model

inputs = Input(shape=(1000, 1000))
encoded = LSTM(latent_dim)(1000)

decoded = RepeatVector(timesteps)(encoded)
decoded = LSTM(input_dim, return_sequences=True)(decoded)

sequence_autoencoder = Model(inputs, decoded)
encoder = Model(inputs, encoded)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-103-a36270061851> in <module>()
#       3
#       4 inputs = Input(shape=(1000, 1000))
# ----> 5 encoded = LSTM(latent_dim)(1000)
#       6
#       7 decoded = RepeatVector(timesteps)(encoded)
#
# NameError: name 'latent_dim' is not defined
